# %%
import requests
from requests import get
from bs4 import BeautifulSoup
from env import github_token, github_username
import acquire
import app
import os
import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import pandas as pd
# Out:
# Fetching page 50 of 50 https://github.com/search?p=50&q=poker&type=Repositories
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# REPOS = ['dickreuter/Poker',
# 'pret/pokered',
# 'ishikota/PyPokerEngine',
# 'andrewprock/pokerstove',
# 'pokerregion/poker',
# 'geobalas/Poker',
# 'pret/pokeruby',
# 'fedden/poker_ai',
# 'pokerth/pokerth',
# 'CharlieHess/slack-poker-bot',
# 'EricSteinberger/PokerRL',
# 'Toxantron/scrumonline',
# 'richarcher/Hatjitsu',
# 'jacobhyphenated/PokerServer',
# 'goldfire/pokersolver',
# 'worldveil/deuces',
# 'kwai/DouZero',
# 'HenryRLee/PokerHandEvaluator',
# 'alexyz/poker',
# 'dickreuter/neuron_poker',
# 'iloveponies/p-p-p-pokerface',
# 'chenosaurus/poker-evaluator',
# 'Tairraos/Poker.JS',
# 'hippich/Bitcoin-Poker-Room',
# 'mjhbell/node-poker',
# 'tianlanlandelan/poker',
# 'Zuehlke/poinz',
# 'christophschmalhofer/poker',
# 'zifeiy/poker-game-demo',
# 'redbooth/scrum-poker-cards',
# 'mdp/JsPoker',
# 'Jeremiah9000/Poker-with-Python',
# 'ginuerzh/poker',
# 'rundef/node-poker-odds-calculator',
# 'wdmir/521266750_qq_com',
# 'datamllab/rlcard',
# 'WangAnXin/poker',
# 'Wizehive/firepoker',
# 'HHSmithy/PokerHandHistoryParser',
# 'iWeslie/PokerCard',
# 'lxr1907/pokers',
# 'brunoscopelliti/poker-holdem-engine',
# 'shuimuliang/qnmahjongserver',
# 'doctording/pomelo_unity_poker_game',
# 'vampserv/node-poker-stack',
# 'floatinghotpot/casino-server',
# 'cschleiden/azure-boards-estimate',
# 'dgurkaynak/slack-poker-planner',
# 'moscow25/deep_draw',
# 'NikolayIT/TexasHoldemGameEngine',
# 'StevenWeathers/thunderdome-planning-poker',
# 'chasembowers/poker-learn',
# 'robolson/ruby-poker',
# 'int8/counterfactual-regret-minimization',
# 'ishikota/PyPokerGUI',
# 'tansey/pycfr',
# 'dannye/pokered-gbc',
# 'chehsunliu/poker',
# 'lifrordi/DeepStack-Leduc',
# 'lbdmxhs/poker',
# 'pierotofy/PokerMuck',
# 'adamsmith/game-theory-poker',
# 'rosbo/texas-holdem-poker-ai',
# 'rotembcohen/pokerBuddyApp',
# 'elpassion/sprint-poker',
# 'sixteenstudio/poker',
# 'russ/openpoker',
# 'ivegner/PokerOmega',
# 'duracellko/planningpoker4azure',
# 'therewillbecode/react-poker',
# 'disdain13/PokeRoadie',
# 'AvengerMoJo/TexasHoldem',
# 'dolotech/Texas-Hold-em-Poker',
# 'pokermania/pokereval',
# 'bubuntux/poker-engine',
# 'yongkangchen/poker-client',
# 'KanishkT123/PokerBot',
# 'aliang/pokerhand-eval',
# 'pokermania/pokernetwork',
# 'mdp/MachinePoker',
# 'atinm/poker-eval',
# 'ashelly/ACE_eval',
# 'michalp21/coms4995-finalproj',
# 'zekyll/OMPEval',
# 'diditforlulz273/PokerRL-Omaha',
# 'benjy3gg/pokeRadar',
# 'bitcoinbrisbane/BitPoker',
# 'yongkangchen/poker-server',
# 'cookpete/poker-odds',
# 'apehex/awesome-poker',
# 'IanSullivan/PokerCFR',
# 'jacobhyphenated/AndroidPokerPlayer',
# 'DevMountain/tic-tac-toe-poker',
# 'matheusml/pwa-planning-poker',
# 'goodspb/poker-algorithm',
# 'v2k/poker-eval',
# 'saschpe/PlanningPoker',
# 'notnil/joker',
# 'lizzie2008/ChinesePoker',
# 'dmorrill10/acpc_poker_gui_client',
# 'aslakhellesoy/poker',
# 'atinm/fpdb',
# 'epifab/pypoker',
# 'bimovidia/planning-poker',
# 'IFS49F/poker',
# 'phstc/javapokertexasholdem',
# 'tokafish/elixir_poker',
# 'Mikhail-MM/React-Poker',
# 'spni/spni.github.io',
# 'ozzi7/Poker-MCCFRM',
# 'coding-blocks/poker',
# 'monicanagent/cypherpoker',
# 'Bryanx/poker',
# 'WayneYe/ScrumPoker',
# 'donnemartin/poker',
# 'pandaant/poker-cfrm',
# 'PhillipTaylor/PokerServer',
# 'dirusali/pokerodds',
# 'code-squad/swift-pokergameapp',
# 'carwow/pokerwars',
# 'rocketacademy/video-poker-bootcamp',
# 'somnusand/Poker',
# 'ylboerner/easyPokerHUD',
# 'andyxhadji/Simple-Poker',
# 'halomademeapc/pokeR',
# 'pokermania/pokerengine',
# 'forestturner/PokerHandRangeCalc',
# 'thlorenz/phe',
# 'schalermthai/pokerhand',
# 'czanoci/Poker',
# 'kripod/mental-poker',
# 'wzdwc/TexasPokerGame',
# 'siimon/Web-Planning-Poker',
# 'igreshev/lightning-poker',
# 'Rainist/pycon-2018-banksalad-holdem',
# 'siavashg87/poker-odds-calc',
# 'philroberts/FPDB-for-OSX',
# 'acebusters/acebusters-frontend',
# 'robopoker/robopoker',
# 'rggibson/open-pure-cfr',
# 'theaigames/poker-engine',
# 'ngokevin/pokery',
# 'scrumpypoker/i18n',
# 'wolo-research/bulldog',
# 'conch76/poker',
# 'DogLooksGood/holdem',
# 'scascar/PokerDeepLearning',
# 'erichkeane/poker2firmwarehacking',
# 'inovex/planning-poker',
# 'whatsdis/pluribus',
# 'ningowood/poker',
# 'evandam/Poker',
# 'elliottneilclark/rs-poker',
# 'allenfrostline/PokerHandsDataset',
# 'NextZeus/poker',
# 'miguelzf/PokerBot',
# 'Ian-MacLeod/Poker-Solver',
# 'AlgorithmsMeetup/PokerHands',
# 'Fubinator/planning-poker-discord-bot',
# 'mdp/hoyle',
# 'VitamintK/pluribus-hand-parser',
# 'nateyolles/slack-pokerbot',
# 'UPRM-Advanced-Programming-Course/PokerMemory',
# 'jgao18/PokerRoom',
# 'near-examples/poker',
# 'wajahatkarim3/EasyFlipView',
# 'ta-data-mexpt/-lab-poker-master',
# 'itb-ie/poker',
# 'ethnt/poker',
# 'mikhailshilkov/FsPokerLogic',
# 'pusabless/texas-poker-engine',
# 'pret/pokerevo',
# 'tsuntsuntsuntsun/Pokerbot',
# 'ta-data-mex/lab-poker-master',
# 'venil7/ScrumPoker',
# 'matthewkennedy5/Poker',
# 'jacobhyphenated/iPadPokerGameClient',
# 'pokerwars/pokerwars.io-starterbot-python',
# 'androidjp/TDD-poker-hands',
# 'Pokereum/pokereum',
# 'rafanoronha/scala-poker',
# 'dperezcabrera/jpoker',
# 'yule/poker-croupier',
# 'garyjh126/MLFYP_Project',
# 'qJake/planning-poker',
# 'wangzi6147/TexasPoker',
# 'luk3vn/web-poker',
# 'AndrejsAbrickis/PlanningPoker',
# 'codescape/jira-scrum-poker',
# 'EvgenyKashin/TensorPoker',
# 'aneopsy/PokerStats',
# 'changhongyan123/mypoker',
# 'jfilliben/poker-sim',
# 'vikas0sharma/ScrumPoker',
# 'zkayser/poker_ex',
# 'thlorenz/hhp',
# 'amiller/instant-poker',
# 'redbooth/planning-time-android',
# 'fangdejia/HwTexasPoker',
# 'surranc20/pokered',
# 'buhrmi/svelte-poker',
# 'PhillipTaylor/texas_holdem',
# 'BlockChainClub/PokerGame',
# 'ylmbtm/PokerCraker',
# 'ozeidan/pokerBot',
# 'kmurf1999/rust_poker',
# 'J-Burnett/PokerPlayer',
# 'pattern/react-poker',
# 'microsoft/matchem-poker-wp',
# 'codesquad-members-2022/swift-pokergame',
# 'onevcat/TexasPoker',
# 'mcostalba/poker',
# 'wwttaozong/Poker',
# 'puzza007/openpoker',
# 'samcoppini/Discord-Poker-Bot',
# 'sky068/PokerLandlord',
# 'dannye/pokered-gen-II',
# 'cschweda/vue-poker',
# 'philou/planning-poker',
# 'bcgraham/pokerserver',
# 'chips-blockchain/pangea-poker',
# 'JaviSoto/SwiftPoker',
# 'wdi-sg/poker_refactor',
# 'nberardi/consensus',
# 'hellomuthu23/planning-poker',
# 'cortesoft/PokerMatic',
# 'ChrisZieba/holdem',
# 'ericdke/PokerHands',
# 'Fossana/cplusplus-cfr-poker-solver',
# 'monicanagent/cypherpoker.js',
# 'tom555cat/Poker2048',
# 'ZenithPoker/ZippySolver',
# 'cornernote/autoit-poker_bot',
# 'gorel/C-Poker-AI',
# 'fattigerlee/poker',
# 'lxr1907/pokers-server',
# 'wkantaros/cloudpoker',
# 'ethansbrown/acpc',
# 'Monadical-SAS/oddslingers.poker',
# 'jtushman/pivotal_tools',
# 'Hazem-Ben-Khalfallah/scrum-poker-planning',
# 'Sharp-Data/Data-Science-Poker-Projects',
# 'bcldvd/real-time-planning-poker',
# 'tansey/js_poker',
# 'TheScarletSword/pokereddeluxe',
# 'ericgjackson/slumbot2019',
# 'iOS-Dev-Kurs/poker',
# 'platatat/SnapCall',
# 'pcafstockf/PokerFace',
# 'mr-feek/global-poker-hand-history-converter-chrome-extension',
# 'predrag-njegovanovic/poker-hand-recognition',
# 'CoinPokerOfficial/poker-decentralized-rng',
# 'Malonrio/Cocos-Shader-Poker',
# 'cwoolner/flex-poker',
# 'ptwu/distributed-texasholdem',
# 'drewtorg/poker',
# 'TNG/next-generation-scrum-poker',
# 'cmccabe/poker-odds',
# 'chmccc/poker',
# 'lean-poker/poker-player-js',
# 'notsapinho/powercord-together',
# 'genjix/kartludox',
# 'gorel/pokerAI',
# 'sudocrystal/CS2-Poker',
# 'BoiseCodeWorks/VideoPoker',
# 'mjwestcott/pypokertools',
# 'yociduo/scrum-planning-poker',
# 'soederpop/poker',
# 'danielmiladinov/Poker',
# 'andrewprock/jpoker',
# 'DabeLong/Two-Card-Poker-CFR-AI',
# 'allenfrostline/Poker',
# 'StefanKarpinski/Cards.jl',
# 'magnusmickelsson/pokeraidbot',
# 'JohnnyJayJay/poker',
# 'axross/aqua',
# 'reutsharabani/minipoker',
# 'udacity/CppND-Game-Server',
# 'zanussbaum/pluribus',
# 'ashelly/PET',
# 'sbnb/poker-js',
# 'huangzy77/PokerRobot',
# 'pokerplatform/Full-Online-Poker-Platform',
# 'Lemoncode/planning-poker-example',
# 'worldveil/gopoker',
# 'peterjiawhite/Superhuman_AI_in_multiplayer_poker_-',
# 'Harpspiel/NewPoker',
# 'marhs/pokerai',
# 'nbcx/poker',
# 'philipok-1/Poker',
# 'guipenedo/PokeRadar',
# 'feliciosan/PokerIT',
# 'miniharryc/poker',
# 'huntrar/PokerNet',
# 'betboy/texas',
# 'codeKonami/poker-hand',
# 'tythorsen/planning-poker',
# 'rundef/poker-odds-calculator',
# 'xcanchal/scrum-poker',
# 'Cysha/casino-holdem',
# 'zygmuntz/kaggle-poker-hands',
# 'brandinho/Poker-Probability-Approximation',
# 'aprey10/open-poker',
# 'kvesteri/python-poker',
# 'cgnicholls/rlpoker',
# 'ynd/poker',
# 'Karsens/pluribus-poker-bot-js',
# 'fogleman/Poker',
# 'boolean-uk/js-poker-challenge',
# 'mouhyi/Poker321',
# 'StarFlight/Poker-Galore',
# 'aniliyidogan/screm.co',
# 'kennethshackleton/SKPokerEval',
# 'sintefmath/QuantumPoker',
# 'zachwaugh/Helveticards',
# 'pokemium/pokered-docs-ja',
# 'Dsummers91/Ethereum-Poker-Dapp',
# 'mikemelch/Card-Games',
# 'rdepena/planningpoker',
# 'nbouscal/poker.hs',
# 'Sanqui/pokered-randomizer',
# 'HerdADVance/maker-holdem',
# 'nidhik/cubeia-agpl',
# 'CWSites/Poker',
# 'aditisrinivas97/Pokerman',
# 'kdub0/hand-isomorphism',
# 'deltacluse/Tkinter_Poker',
# 'zkayser/pokerex_client',
# 'dickreuter/PokerEquityCalculator',
# 'tshadowknight/Pokemon-Roaming-Red',
# 'lean-poker/poker-player-ruby',
# 'vpj/poker',
# 'pokereosteam/PokerEOS',
# 'valterbarros/scrum-poker',
# 'itb-ie/poker_homework',
# 'ryan112358/poker-bot',
# 'zxqx/poker',
# 'mingzijian/pokers',
# 'brucetie/pokerface',
# 'tangentforks/TwoPlusTwoHandEvaluator',
# 'EricSteinberger/Deep-CFR',
# 'steve-ng/pokerface-nft',
# 'thinkbox/poker-1',
# 'h3rc4r/lab-poker-odds',
# 'Mullen-High-School/Draw-Poker',
# 'Rangi42/polished-map',
# 'twa-camp-2016/poker-21',
# 'scrubmx/poker',
# 'edavis03/poker-hands',
# 'Froren/OpenToolchainPoker',
# 'Sebazzz/PokerTime',
# 'vkolagotla/DevOpsPoker',
# 'Deltanium/PokeRadar',
# 'WDI-SEA/poker_tournament',
# 'mettoboshi/poker-game',
# 'tamlhp/deepbot-poker',
# 'chrisjeng/Poker',
# 'GavinJoyce/PokerCards',
# 'VasylYaremkiv/poker',
# 'codejens/PokerGame',
# 'JosephYao/Kata-PokerHands',
# 'ucsb-cs56-projects/cs56-games-poker',
# 'haffizaliraza/poker-ruby',
# 'vilotchild/AwesomePokerGame',
# 'timhaley94/holdem',
# 'mangoknight/dexas-poker',
# 'pandaant/poker-mcts',
# 'Pobermeier/vintage-poker',
# 'chips-blockchain/bet',
# 'mr-feek/global-poker-hand-history-converter',
# 'icescrum/iceScrum-plugin-planning-poker',
# 'Fossana/discounted-cfr-poker-solver',
# 'kyrcha/poker',
# 'danielpaz6/Poker-Hand-Evaluator',
# 'GeekLaunch/poker',
# 'tfbninja/Poker',
# 'axross/poker',
# 'phipex/PokerTest',
# 'cs3243-project-group-18/poker-ai',
# '3pillarlabs/scrumpoker',
# 'mihhailnovik/jSim',
# 'xcyuzhen/Poker_client_pomelo',
# 'jeffusan/yokohama-holdem',
# 'hlcfan/pokr',
# 'iamsap/poker',
# 'WDI-SEA/express-poker-teams',
# 'pokerth/pokerth-live',
# 'xumingthepoet/texas_poker',
# 'Z8264/poker-calculator',
# 'szantopeter/poker-player-java',
# 'pj4533/PokerNowGrabber',
# 'koffeinfrei/planning-poker',
# 'SoboLAN/pokerenlighter-simulator',
# 'ChengTsang/Potential-Aware-Abstraction-In-Texas-Hold-em-Poker',
# 'EricMWalton/Fast-Poker-Odds',
# 'byronsha/poker_playhouse',
# 'jjulian/pitboss',
# 'matt404/Pointing.Poker',
# 'sixteenstudio/poker-env',
# 'rux-pizza/poker-ai',
# 'Dosugamea/PokerBot',
# 'karinqe/poker',
# 'Dabomstew/pokered-speedchoice',
# 'jamesmacaulay/poker-hands',
# 'GoldPoker/GoldPoker-coin',
# 'boldpoker/poker-shuffle',
# 'eduardo/planning-poker-timer',
# 'Gorazdo/Planning-Poker',
# 'Josh-TX/Poker',
# 'zanezgame/Poker',
# 'ekzhu/planning-poker',
# 'melickm/OpenToolchainPoker',
# 'bovle/fixed_limit_poker',
# 'connor21/DevOpsPoker',
# 'mcwp98/pokernet',
# 'pj4533/PokerNowKit',
# 'aparrett/poker-ui-deprecated',
# 'luofanrain/poker',
# 'rrylee/phppoker',
# 'travisby/altcoinpokerjs',
# 'wizardwerdna/pokerstats',
# 'shige0501/android-sdk-pokeri',
# 'adityanaag3/planning-poker-salesforce',
# 'izqui/Poker.swift',
# 'Yaoir/VideoPoker-Go-WebAssembly',
# 'digao-dalpiaz/Planning-Poker',
# 'hh2010/hunl',
# 'xcyuzhen/Poker_server_pomelo',
# 'lzientek/pokerPlanning',
# 'Nisarg12/pokeruby-tools',
# 'ta-datapt-bcn/lab-poker-odds',
# 'Pik-9/PokerTH-Tracker',
# 'technologiespro/poker-core',
# 'mproberts/smallblind',
# 'studiomobile/poker-eval-node',
# 'beli-sk/pokercards',
# 'jamak/pokerbot',
# 'jacobhyphenated/JQMPokerPlayerClient',
# 'montyaahad/PokerStarsBot',
# 'huderlem/pokered_battle_factory',
# 'huderlem/pokered_battle_factory',
# 'tue-5ARA0-2021-Q3/poker-server-backend',
# 'LRFalk01/pokerboy',
# 'norkator/poker-pocket-backend',
# 'juhank/poker',
# 'girving/poker',
# 'Bitou2k/PokeRPG',
# 'aparrett/poker-api-deprecated',
# 'aha-develop/planning-poker',
# 'rdvdijk/ruby-poker',
# 'tomo-tomoarch/YokosukaPokerVer0.2',
# 'EmeraldCityProgrammingGroup/tracker_poker',
# 'COO-EACH-USP-2021/Poker-ACH2003-04',
# 'Zack-Tillotson/Simple-Poker-Classification',
# 'samuelneff/poker-tutorial',
# 'kmurf1999/HoldemSolver',
# 'AussieSeaweed/pokerface',
# 'syurisuzuki/PokerAndCoinPusher',
# 'Trantect/PlanningPoker',
# 'einstein95/pokered-de',
# 'ostigter/texasholdem-java',
# 'shige0501/android-sdk-pokeri-v2',
# 'jbPokerStarsSolutions/PokerStars-API',
# 'FilippoMandrini/Progetto-J',
# 'wangxiaomo/Poker',
# 'FrancoisHar/Poker',
# 'linuz/Facebook-Auto-Poker',
# 'carlosreneas/parcialPoker',
# 'kabirsingh2004/Discord-Mini-Games-Bot',
# 'omarshammas/pyPoker-Texas-HoldEm',
# 'AtlantaMobileDevGroup/planning_poker',
# 'robinv/scrum-poker-frontend',
# 'Ajnasz/scrum-poker',
# 'lean-poker/poker-player-go',
# 'Dabomstew/pokecrystal-speedchoice-legacy',
# 'huangtao/qipai',
# 'jroliveira/planning-poker-game',
# 'yeoedward/poker',
# 'AKerr94/OFCP-AI',
# 'thepokerlogic/oddscalc',
# 'riddlesio/poker-engine-java',
# 'listingslab/react-playing-cards',
# 'RobertCorey/column-poker',
# 'bjrnmrtns/poker',
# 'treyarnold/poker-face',
# 'coffee4tw/poker-hhdb',
# 'mdashx/pangea-poker-frontend',
# 'tterava/PokerTrainingFramework',
# 'charlesabarnes/pointing-poker',
# 'phongcao/pokerbot',
# 'nikita-volkov/ptr-poker',
# 'beachgrub/PokerHandSolidity',
# 'nowakowsky/PokerStars',
# 'Ahineya/js-workshop-poker-boilerplate',
# 'David-H-Bolton/PokerEval',
# 'IMGameDesigner/PokerGame',
# 'houen/PokerFace',
# 'ngocbd/pokerserver',
# 'mikaelbr/AI-Poker-Player',
# 'ProPanek/PlanningPoker']

# %%
pd.read_json("data.json")
# Out:
#                          repo      language  \
# 0            dickreuter/Poker        Python
# 1                pret/pokered      Assembly
# 2      ishikota/PyPokerEngine        Python
# 3      andrewprock/pokerstove           C++
# 4           pokerregion/poker        Python
# ..                        ...           ...
# 495  IMGameDesigner/PokerGame    JavaScript
# 496           houen/PokerFace  ActionScript
# 497        ngocbd/pokerserver          Java
# 498  mikaelbr/AI-Poker-Player        Python
# 499    ProPanek/PlanningPoker    JavaScript
#
#                                        readme_contents
# 0    Deep mind pokerbot for pokerstars, partypoker ...
# 1    # Pokémon Red and Blue [![Build Status][ci-bad...
# 2    # PyPokerEngine\n\n[![Build Status](https://tr...
# 3    PokerStove\n==========\n\n[![OpenHUB Metrics](...
# 4    Poker framework for Python\n==================...
# ..                                                 ...
# ...

# %%
contents = pd.read_json("data.json")
contents

# %%
readme = contents.readme_contents

# %%
readme

# %%
df = contents

# %%
df
# Out:
#                          repo      language  \
# 0            dickreuter/Poker        Python
# 1                pret/pokered      Assembly
# 2      ishikota/PyPokerEngine        Python
# 3      andrewprock/pokerstove           C++
# 4           pokerregion/poker        Python
# ..                        ...           ...
# 495  IMGameDesigner/PokerGame    JavaScript
# 496           houen/PokerFace  ActionScript
# 497        ngocbd/pokerserver          Java
# 498  mikaelbr/AI-Poker-Player        Python
# 499    ProPanek/PlanningPoker    JavaScript
#
#                                        readme_contents
# 0    Deep mind pokerbot for pokerstars, partypoker ...
# 1    # Pokémon Red and Blue [![Build Status][ci-bad...
# 2    # PyPokerEngine\n\n[![Build Status](https://tr...
# 3    PokerStove\n==========\n\n[![OpenHUB Metrics](...
# 4    Poker framework for Python\n==================...
# ..                                                 ...
# ...

# %%
ADDITIONAL_STOPWORDS = ['r', 'u', '2', 'ltgt']

def clean(text):
    'A simple function to cleanup text data'
    wnl = nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('english') + ADDITIONAL_STOPWORDS
    text = (unicodedata.normalize('NFKD', text)
             .encode('ascii', 'ignore')
             .decode('utf-8', 'ignore')
             .lower())
    words = re.sub(r'[^\w\s]', '', text).split()
    return [wnl.lemmatize(word) for word in words if word not in stopwords]

# %%
df.language.value_counts()
# Out:
# JavaScript          102
# Python               88
# Java                 59
# C++                  31
# C#                   26
# TypeScript           23
# Ruby                 17
# C                    15
# PHP                  14
# Jupyter Notebook     11
# Assembly             11
# Go                   11
# Swift                 7
# Objective-C           5
# Elixir                5
# HTML                  5
# Erlang                4
# ActionScript          4
# CSS                   4
# Clojure               4
# Rust                  4
# Lua                   3
# Scala                 3
# Haskell               2
# Pascal                2
# Dart                  2
# Vue                   2
# CoffeeScript          2
# Kotlin                2
# Shell                 2
# Svelte                2
# Roff                  2
# F#                    1
# CMake                 1
# Julia                 1
# Elm                   1
# Groovy                1
# Apex                  1
# ...

# %%
language = pd.concat([df.language.value_counts(),
                    df.language.value_counts(normalize=True)], axis=1)
language.columns = ['n', 'percent']
language
# Out:
#                     n   percent
# JavaScript        102  0.212058
# Python             88  0.182952
# Java               59  0.122661
# C++                31  0.064449
# C#                 26  0.054054
# TypeScript         23  0.047817
# Ruby               17  0.035343
# C                  15  0.031185
# PHP                14  0.029106
# Jupyter Notebook   11  0.022869
# Assembly           11  0.022869
# Go                 11  0.022869
# Swift               7  0.014553
# Objective-C         5  0.010395
# Elixir              5  0.010395
# HTML                5  0.010395
# Erlang              4  0.008316
# ActionScript        4  0.008316
# CSS                 4  0.008316
# Clojure             4  0.008316
# Rust                4  0.008316
# Lua                 3  0.006237
# Scala               3  0.006237
# Haskell             2  0.004158
# Pascal              2  0.004158
# Dart                2  0.004158
# Vue                 2  0.004158
# CoffeeScript        2  0.004158
# ...

# %%
def show_counts_and_ratios(df, column):
    """
    Takes in a dataframe and a string of a single column
    Returns a dataframe with absolute value counts and percentage value counts
    """
    language = pd.concat([df[column].value_counts(),
                    df[column].value_counts(normalize=True)], axis=1)
    language.columns = ['n', 'percent']
    language
    return language

show_counts_and_ratios(df, "language")
# Out:
#                     n   percent
# JavaScript        102  0.212058
# Python             88  0.182952
# Java               59  0.122661
# C++                31  0.064449
# C#                 26  0.054054
# TypeScript         23  0.047817
# Ruby               17  0.035343
# C                  15  0.031185
# PHP                14  0.029106
# Jupyter Notebook   11  0.022869
# Assembly           11  0.022869
# Go                 11  0.022869
# Swift               7  0.014553
# Objective-C         5  0.010395
# Elixir              5  0.010395
# HTML                5  0.010395
# Erlang              4  0.008316
# ActionScript        4  0.008316
# CSS                 4  0.008316
# Clojure             4  0.008316
# Rust                4  0.008316
# Lua                 3  0.006237
# Scala               3  0.006237
# Haskell             2  0.004158
# Pascal              2  0.004158
# Dart                2  0.004158
# Vue                 2  0.004158
# CoffeeScript        2  0.004158
# ...

# %%
def basic_clean(readme_contents:str):
    """ Performs basic cleaning of text string, article, by switching all letters to lowecase, normalizing unicode characters, 
    and replacing everything that is not a letter, number, whitespace, or single quote."""
    # Convert text to lowercase
    readme_contents = readme_contents.lower()
    
    # Remove accented characteries. Normalize removes inconsistencies in unicode character encoding.
    # Encode converts string to ASCII and decode returns the bytes into string.
    readme_contents = unicodedata.normalize('NFKD', readme_contents)\
    .encode('ascii', 'ignore')\
    .decode('utf-8', 'ignore')

    # remove anything that is not a through z, a number, a single quote, or whitespace
    readme_contents = re.sub(r"[^a-z0-9'\s]", '', article)
    
    return readme_contents

# %%
def tokenize(readme_contents:str):
    """ Takes in a string, article, and tokenizes all words """
    
    tokenizer = nltk.tokenize.ToktokTokenizer()

    return tokenizer.tokenize(readme_contents, return_str=True)

def stem(readme_contents: str):
    """ Takes in a string, article, and returns text after applying stemming using Porter method """
    
    ps = nltk.porter.PorterStemmer()

    stems = [ps.stem(word) for word in readme_contents.split()]
    readme_contents_stemmed = ' '.join(stems)
    
    return readme_contents_stemmed

# %% [raw]
# wnl = nltk.stem.WordNetLemmatizer()
#
# oford in readme_contents.split():
#     print('stem:', ps.stem(word), '-- lemma:', wnl.lemmatize(word))

# %%
def remove_stopwords(readme_contents: str, extra_words: list, exclude_words: list):
    """ Accepts string (article) as argument and returns text after removing all the stopwords.
    extra_words: any additional stop words to include (these words will be removed from the article)
    exclude_words: any words we do not want to remove. These words are removed from the stopwords list and will remain in article """
    
    stopword_list = stopwords.words('english')

    [stopword_list.append(word_to_add) for word_to_add in extra_words if word_to_add not in stopword_list]
    [stopword_list.remove(to_remove) for to_remove in exclude_words if to_remove in stopword_list]

    words = readme_contents.split()
    filtered_words = [w for w in words if w not in stopword_list]

    # print('Removed {} stopwords'.format(len(words) - len(filtered_words)))

    readme_contents_without_stopwords = ' '.join(filtered_words)
    
    return readme_contents_without_stopwords

def prepare_df(df, extra_words = [], exclude_words = []):
    """Adds columns for cleaned, stemmed, and lemmatized data in dataframe """
    # Create cleaned data column of content
    df['clean'] = df.original.apply(basic_clean).apply(tokenize).apply(remove_stopwords,
                                                       extra_words = extra_words,
                                                       exclude_words = exclude_words)
    
    # Create stemmed column with stemmed version of cleaned data
    df['stemmed'] = df.clean.apply(tokenize).apply(stem).apply(remove_stopwords,
                                                       extra_words = extra_words,
                                                       exclude_words = exclude_words)

    # Create lemmatized column with lemmatized version of cleaned data
    df['lemmatized'] = df.clean.apply(tokenize).apply(lemmatize).apply(remove_stopwords,
                                                       extra_words = extra_words,
                                                       exclude_words = exclude_words)
    
    return df
    
    
    
def train_validate_test_split(df, target, seed=123):
    '''
    This function takes in a dataframe, the name of the target variable
    (for stratification purposes), and an integer for a setting a seed
    and splits the data into train, validate and test. 
    Test is 20% of the original dataset, validate is .30*.80= 24% of the 
    original dataset, and train is .70*.80= 56% of the original dataset. 
    The function returns, in this order, train, validate and test dataframes. 
    '''
    train_validate, test = train_test_split(df, test_size=0.2, 
                                            random_state=seed, 
                                            stratify=df[target])
    train, validate = train_test_split(train_validate, test_size=0.3, 
                                       random_state=seed,
                                       stratify=train_validate[target])
    return train, validate, test

# %%
df['text_cleaned_lem'] = df.readme_contents.apply(lemmatize)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/vb/2f5pphz943qdprdg5zvhqsbm0000gp/T/ipykernel_48456/4283623368.py in <module>
# ----> 1 df['text_cleaned_lem'] = df.readme_contents.apply(lemmatize)
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
# ...
