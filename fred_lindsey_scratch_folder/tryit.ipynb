# %%
import os
import json
import requests
import env
from typing import Dict, List, Optional, Union, cast
from requests import get
from bs4 import BeautifulSoup

from env import github_token, github_username
    
    
url = 'https://github.com/search?q=poker'
headers = {"Authorization": f"token {github_token}", "User-Agent": github_username}
response = get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
response.text

soup.find_all('a')
# Out:
# [<a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>,
#  <a aria-label="Homepage" class="mr-4 color-fg-inherit" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
#  <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
#  <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
#  </svg>
#  </a>,
#  <a class="d-inline-block d-lg-none f5 no-underline border color-border-default rounded-2 px-2 py-1 mr-3 mr-sm-5 color-fg-inherit" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="5f6a0e1a1e75fb4efd0ab83bcaf0fd2b2cfe459b2b18d90482ba39dbd60c13aa" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2Fsearch&amp;source=header">
#                Sign up
#              </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Features","label":"ref_page:/search?q=poker;ref_cta:Features;"}' href="/features">
#        Features
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Mobile","label":"ref_page:/search?q=poker;ref_cta:Mobile;"}' href="/mobile">
#        Mobile
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_page:/search?q=poker;ref_cta:Actions;"}' href="/features/actions">
#        Actions
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Codespaces","label":"ref_page:/search?q=poker;ref_cta:Codespaces;"}' href="/features/codespaces">
#        Codespaces
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Copilot","label":"ref_page:/search?q=poker;ref_cta:Copilot;"}' href="/features/copilot">
#        Copilot
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Packages","label":"ref_page:/search?q=poker;ref_cta:Packages;"}' href="/features/packages">
#        Packages
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Security","label":"ref_page:/search?q=poker;ref_cta:Security;"}' href="/features/security">
#        Security
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Code review","label":"ref_page:/search?q=poker;ref_cta:Code review;"}' href="/features/code-review">
#        Code review
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Issues","label":"ref_page:/search?q=poker;ref_cta:Issues;"}' href="/features/issues">
#        Issues
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Discussions","label":"ref_page:/search?q=poker;ref_cta:Discussions;"}' href="/features/discussions">
#        Discussions
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Integrations","label":"ref_page:/search?q=poker;ref_cta:Integrations;"}' href="/features/integrations">
#        Integrations
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to GitHub Sponsors","label":"ref_page:/search?q=poker;ref_cta:GitHub Sponsors;"}' href="/sponsors">
#        GitHub Sponsors
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Customer stories","label":"ref_page:/search?q=poker;ref_cta:Customer stories;"}' href="/customer-stories">
#        Customer stories
#  </a>,
#  <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Team","label":"ref_page:/search?q=poker;ref_cta:Team;"}' href="/team">Team</a>,
#  <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Enterprise","label":"ref_page:/search?q=poker;ref_cta:Enterprise;"}' href="/enterprise">Enterprise</a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Explore GitHub","label":"ref_page:/search?q=poker;ref_cta:Explore GitHub;"}' href="/explore">
#        Explore GitHub
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Topics","label":"ref_page:/search?q=poker;ref_cta:Topics;"}' href="/topics">
#        Topics
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Collections","label":"ref_page:/search?q=poker;ref_cta:Collections;"}' href="/collections">
#        Collections
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Trending","label":"ref_page:/search?q=poker;ref_cta:Trending;"}' href="/trending">
#        Trending
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Skills","label":"ref_page:/search?q=poker;ref_cta:Skills;"}' href="https://skills.github.com/">
#        Skills
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Sponsors","label":"ref_page:/search?q=poker;ref_cta:GitHub Sponsors;"}' href="/sponsors/explore">
#        GitHub Sponsors
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Open source guides","label":"ref_page:/search?q=poker;ref_cta:Open source guides;"}' href="https://opensource.guide">
#        Open source guides
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to The ReadME Project","label":"ref_page:/search?q=poker;ref_cta:The ReadME Project;"}' href="/readme">
#        The ReadME Project
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Events","label":"ref_page:/search?q=poker;ref_cta:Events;"}' href="/events">
#        Events
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Community forum","label":"ref_page:/search?q=poker;ref_cta:Community forum;"}' href="https://github.community">
#        Community forum
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Education","label":"ref_page:/search?q=poker;ref_cta:GitHub Education;"}' href="https://education.github.com">
#        GitHub Education
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Stars program","label":"ref_page:/search?q=poker;ref_cta:GitHub Stars program;"}' href="https://stars.github.com">
#        GitHub Stars program
#  </a>,
#  <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Marketplace","label":"ref_page:/search?q=poker;ref_cta:Marketplace;"}' href="/marketplace">Marketplace</a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Plans","label":"ref_page:/search?q=poker;ref_cta:Plans;"}' href="/pricing">
#        Plans
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Compare plans","label":"ref_page:/search?q=poker;ref_cta:Compare plans;"}' href="/pricing#compare-features">
#        Compare plans
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Contact Sales","label":"ref_page:/search?q=poker;ref_cta:Contact Sales;"}' href="https://github.com/enterprise/contact">
#        Contact Sales
#  </a>,
#  <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Education","label":"ref_page:/search?q=poker;ref_cta:Education;"}' href="https://education.github.com">
#        Education
#  </a>,
#  <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="suggestion" href="" tabindex="-1">
#  <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
#  <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
#  </svg>
#  <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
#  </svg>
#  </div>
#  <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
#  <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
#  </div>
#  <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
#  <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#          Search
#        </span>
#  <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#          All GitHub
#        </span>
#  <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
#  </div>
#  <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#        Jump to
#        <span class="d-inline-block ml-1 v-align-middle">↵</span>
#  </div>
#  </a>,
#  <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="scoped_search" href="" tabindex="-1">
#  <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
#  <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
#  </svg>
#  <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
#  </svg>
#  </div>
#  <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
#  <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
#  </div>
#  <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
#  <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#          Search
#        </span>
#  <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#          All GitHub
#        </span>
#  <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
#  </div>
#  <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#        Jump to
#        <span class="d-inline-block ml-1 v-align-middle">↵</span>
#  </div>
#  </a>,
#  <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="owner_scoped_search" href="" tabindex="-1">
#  <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
#  <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
#  </svg>
#  <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
#  </svg>
#  </div>
#  <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
#  <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
#  </div>
#  <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
#  <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#          Search
#        </span>
#  <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#          All GitHub
#        </span>
#  <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
#  </div>
#  <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#        Jump to
#        <span class="d-inline-block ml-1 v-align-middle">↵</span>
#  </div>
#  </a>,
#  <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="global_search" href="" tabindex="-1">
#  <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
#  <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
#  </svg>
#  <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
#  </svg>
#  </div>
#  <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
#  <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
#  </div>
#  <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
#  <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#          Search
#        </span>
#  <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#          All GitHub
#        </span>
#  <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
#  </div>
#  <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#        Jump to
#        <span class="d-inline-block ml-1 v-align-middle">↵</span>
#  </div>
#  </a>,
#  <a class="HeaderMenu-link flex-shrink-0 no-underline" data-ga-click="(Logged out) Header, clicked Sign in, text:sign-in" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header menu","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="575bc10e4e3e40a9ba05bc350d100dfce849b0f8a6751f9be206e38fe0823bb3" href="/login?return_to=https%3A%2F%2Fgithub.com%2Fsearch%3Fq%3Dpoker">
#              Sign in
#            </a>,
#  <a class="HeaderMenu-link flex-shrink-0 d-inline-block no-underline border color-border-default rounded px-2 py-1" data-analytics-event='{"category":"Sign up","action":"click to sign up for account","label":"ref_page:/search;ref_cta:Sign up;ref_loc:header logged out"}' data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header menu","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="575bc10e4e3e40a9ba05bc350d100dfce849b0f8a6751f9be206e38fe0823bb3" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2Fsearch&amp;source=header">
#              Sign up
#            </a>,
#  <a class="menu-item selected" href="/search?q=poker&amp;type=repositories">Repositories<span class="ml-1 js-codesearch-count Counter Counter--primary" data-search-type="Repositories">31K</span></a>,
#  <a class="menu-item" href="/search?q=poker&amp;type=code">Code<include-fragment src="https://github.com/search/count?q=poker&amp;type=Code"></include-fragment></a>,
#  <a class="menu-item" href="/search?q=poker&amp;type=commits">Commits<include-fragment src="https://github.com/search/count?q=poker&amp;type=Commits"></include-fragment></a>,
#  <a class="menu-item" href="/search?q=poker&amp;type=issues">Issues<include-fragment src="https://github.com/search/count?q=poker&amp;type=Issues"></include-fragment></a>,
#  <a class="menu-item" href="/search?q=poker&amp;type=discussions">Discussions<include-fragment src="https://github.com/search/count?q=poker&amp;type=Discussions"></include-fragment></a>,
#  <a class="menu-item" href="/search?q=poker&amp;type=registrypackages">Packages<include-fragment src="https://github.com/search/count?q=poker&amp;type=RegistryPackages"></include-fragment></a>,
#  <a class="menu-item" href="/search?q=poker&amp;type=marketplace">Marketplace<include-fragment src="https://github.com/search/count?q=poker&amp;type=Marketplace"></include-fragment></a>,
#  <a class="menu-item" href="/search?q=poker&amp;type=topics">Topics<include-fragment src="https://github.com/search/count?q=poker&amp;type=Topics"></include-fragment></a>,
#  <a class="menu-item" href="/search?q=poker&amp;type=wikis">Wikis<include-fragment src="https://github.com/search/count?q=poker&amp;type=Wikis"></include-fragment></a>,
#  <a class="menu-item" href="/search?q=poker&amp;type=users">Users<include-fragment src="https://github.com/search/count?q=poker&amp;type=Users"></include-fragment></a>,
#  <a class="UnderlineNav-item flex-shrink-0 selected" href="/search?q=poker&amp;type=repositories">Repositories<span class="ml-1 js-codesearch-count Counter Counter--primary" data-search-type="Repositories">31K</span></a>,
#  <a class="UnderlineNav-item flex-shrink-0" href="/search?q=poker&amp;type=code">Code<span class="d-none js-codesearch-deferred-count" data-search-type="Code"></span></a>,
#  <a class="UnderlineNav-item flex-shrink-0" href="/search?q=poker&amp;type=commits">Commits<span class="d-none js-codesearch-deferred-count" data-search-type="Commits"></span></a>,
#  <a class="UnderlineNav-item flex-shrink-0" href="/search?q=poker&amp;type=issues">Issues<span class="d-none js-codesearch-deferred-count" data-search-type="Issues"></span></a>,
#  <a class="UnderlineNav-item flex-shrink-0" href="/search?q=poker&amp;type=discussions">Discussions<span class="d-none js-codesearch-deferred-count" data-search-type="Discussions"></span></a>,
#  <a class="UnderlineNav-item flex-shrink-0" href="/search?q=poker&amp;type=registrypackages">Packages<span class="d-none js-codesearch-deferred-count" data-search-type="RegistryPackages"></span></a>,
#  <a class="UnderlineNav-item flex-shrink-0" href="/search?q=poker&amp;type=marketplace">Marketplace<span class="d-none js-codesearch-deferred-count" data-search-type="Marketplace"></span></a>,
#  <a class="UnderlineNav-item flex-shrink-0" href="/search?q=poker&amp;type=topics">Topics<span class="d-none js-codesearch-deferred-count" data-search-type="Topics"></span></a>,
#  <a class="UnderlineNav-item flex-shrink-0" href="/search?q=poker&amp;type=wikis">Wikis<span class="d-none js-codesearch-deferred-count" data-search-type="Wikis"></span></a>,
#  <a class="UnderlineNav-item flex-shrink-0" href="/search?q=poker&amp;type=users">Users<span class="d-none js-codesearch-deferred-count" data-search-type="Users"></span></a>,
#  <a class="filter-item" href="/search?l=Java&amp;q=poker&amp;type=Repositories">
#  <span class="count">5,681</span>
#                Java
#  </a>,
#  <a class="filter-item" href="/search?l=JavaScript&amp;q=poker&amp;type=Repositories">
#  <span class="count">4,954</span>
#                JavaScript
#  </a>,
#  <a class="filter-item" href="/search?l=Python&amp;q=poker&amp;type=Repositories">
#  <span class="count">4,035</span>
#                Python
#  </a>,
#  <a class="filter-item" href="/search?l=C%23&amp;q=poker&amp;type=Repositories">
#  <span class="count">1,957</span>
#                C#
#  </a>,
#  <a class="filter-item" href="/search?l=Ruby&amp;q=poker&amp;type=Repositories">
#  <span class="count">1,473</span>
#                Ruby
#  </a>,
#  <a class="filter-item" href="/search?l=C%2B%2B&amp;q=poker&amp;type=Repositories">
#  <span class="count">1,410</span>
#                C++
#  </a>,
#  <a class="filter-item" href="/search?l=TypeScript&amp;q=poker&amp;type=Repositories">
#  <span class="count">1,277</span>
#                TypeScript
#  </a>,
#  <a class="filter-item" href="/search?l=HTML&amp;q=poker&amp;type=Repositories">
#  <span class="count">960</span>
#                HTML
#  </a>,
#  <a class="filter-item" href="/search?l=PHP&amp;q=poker&amp;type=Repositories">
#  <span class="count">574</span>
#                PHP
#  </a>,
#  <a class="filter-item" href="/search?l=C&amp;q=poker&amp;type=Repositories">
#  <span class="count">545</span>
#                C
#  </a>,
#  <a class="f6" href="/search/advanced?q=poker&amp;type=Repositories">Advanced search</a>,
#  <a href="https://docs.github.com/articles/about-searching-on-github/">search help section</a>,
#  <a href="https://docs.github.com/articles/searching-repositories"><svg aria-label="Help" class="octicon octicon-link-external" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M10.604 1h4.146a.25.25 0 01.25.25v4.146a.25.25 0 01-.427.177L13.03 4.03 9.28 7.78a.75.75 0 01-1.06-1.06l3.75-3.75-1.543-1.543A.25.25 0 0110.604 1zM3.75 2A1.75 1.75 0 002 3.75v8.5c0 .966.784 1.75 1.75 1.75h8.5A1.75 1.75 0 0014 12.25v-3.5a.75.75 0 00-1.5 0v3.5a.25.25 0 01-.25.25h-8.5a.25.25 0 01-.25-.25v-8.5a.25.25 0 01.25-.25h3.5a.75.75 0 000-1.5h-3.5z" fill-rule="evenodd"></path>
#  </svg></a>,
#  <a href="https://docs.github.com/articles/searching-code"><svg aria-label="Help" class="octicon octicon-link-external" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M10.604 1h4.146a.25.25 0 01.25.25v4.146a.25.25 0 01-.427.177L13.03 4.03 9.28 7.78a.75.75 0 01-1.06-1.06l3.75-3.75-1.543-1.543A.25.25 0 0110.604 1zM3.75 2A1.75 1.75 0 002 3.75v8.5c0 .966.784 1.75 1.75 1.75h8.5A1.75 1.75 0 0014 12.25v-3.5a.75.75 0 00-1.5 0v3.5a.25.25 0 01-.25.25h-8.5a.25.25 0 01-.25-.25v-8.5a.25.25 0 01.25-.25h3.5a.75.75 0 000-1.5h-3.5z" fill-rule="evenodd"></path>
#  </svg></a>,
#  <a href="https://docs.github.com/articles/searching-issues"><svg aria-label="Help" class="octicon octicon-link-external" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M10.604 1h4.146a.25.25 0 01.25.25v4.146a.25.25 0 01-.427.177L13.03 4.03 9.28 7.78a.75.75 0 01-1.06-1.06l3.75-3.75-1.543-1.543A.25.25 0 0110.604 1zM3.75 2A1.75 1.75 0 002 3.75v8.5c0 .966.784 1.75 1.75 1.75h8.5A1.75 1.75 0 0014 12.25v-3.5a.75.75 0 00-1.5 0v3.5a.25.25 0 01-.25.25h-8.5a.25.25 0 01-.25-.25v-8.5a.25.25 0 01.25-.25h3.5a.75.75 0 000-1.5h-3.5z" fill-rule="evenodd"></path>
#  </svg></a>,
#  <a href="https://docs.github.com/articles/searching-users"><svg aria-label="Help" class="octicon octicon-link-external" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M10.604 1h4.146a.25.25 0 01.25.25v4.146a.25.25 0 01-.427.177L13.03 4.03 9.28 7.78a.75.75 0 01-1.06-1.06l3.75-3.75-1.543-1.543A.25.25 0 0110.604 1zM3.75 2A1.75 1.75 0 002 3.75v8.5c0 .966.784 1.75 1.75 1.75h8.5A1.75 1.75 0 0014 12.25v-3.5a.75.75 0 00-1.5 0v3.5a.25.25 0 01-.25.25h-8.5a.25.25 0 01-.25-.25v-8.5a.25.25 0 01.25-.25h3.5a.75.75 0 000-1.5h-3.5z" fill-rule="evenodd"></path>
#  </svg></a>,
#  <a aria-checked="true" class="select-menu-item" data-pjax="true" data-pjax-preserve-scroll="true" href="/search?o=desc&amp;q=poker&amp;s=&amp;type=Repositories" role="menuitemradio">
#  <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="select-menu-item-text" data-menu-button-text="">Best match</span>
#  </a>,
#  <a aria-checked="false" class="select-menu-item" data-pjax="true" data-pjax-preserve-scroll="true" href="/search?o=desc&amp;q=poker&amp;s=stars&amp;type=Repositories" role="menuitemradio">
#  <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="select-menu-item-text" data-menu-button-text="">Most stars</span>
#  </a>,
#  <a aria-checked="false" class="select-menu-item" data-pjax="true" data-pjax-preserve-scroll="true" href="/search?o=asc&amp;q=poker&amp;s=stars&amp;type=Repositories" role="menuitemradio">
#  <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="select-menu-item-text" data-menu-button-text="">Fewest stars</span>
#  </a>,
#  <a aria-checked="false" class="select-menu-item" data-pjax="true" data-pjax-preserve-scroll="true" href="/search?o=desc&amp;q=poker&amp;s=forks&amp;type=Repositories" role="menuitemradio">
#  <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="select-menu-item-text" data-menu-button-text="">Most forks</span>
#  </a>,
#  <a aria-checked="false" class="select-menu-item" data-pjax="true" data-pjax-preserve-scroll="true" href="/search?o=asc&amp;q=poker&amp;s=forks&amp;type=Repositories" role="menuitemradio">
#  <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="select-menu-item-text" data-menu-button-text="">Fewest forks</span>
#  </a>,
#  <a aria-checked="false" class="select-menu-item" data-pjax="true" data-pjax-preserve-scroll="true" href="/search?o=desc&amp;q=poker&amp;s=updated&amp;type=Repositories" role="menuitemradio">
#  <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="select-menu-item-text" data-menu-button-text="">Recently updated</span>
#  </a>,
#  <a aria-checked="false" class="select-menu-item" data-pjax="true" data-pjax-preserve-scroll="true" href="/search?o=asc&amp;q=poker&amp;s=updated&amp;type=Repositories" role="menuitemradio">
#  <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="select-menu-item-text" data-menu-button-text="">Least recently updated</span>
#  </a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":1,"click_id":55018634,"result":{"id":55018634,"global_relay_id":"MDEwOlJlcG9zaXRvcnk1NTAxODYzNA==","model_name":"Repository","url":"https://github.com/dickreuter/Poker"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="e1766e31a417865d8259e97fcfbe3552e5b99662e161136ccceb94deb40ddae6" href="/dickreuter/Poker">dickreuter/<em>Poker</em></a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:poker,repository_id:55018634,repository_nwo:dickreuter/Poker,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/poker" title="Topic: poker">
#    poker
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:artificial-intelligence,repository_id:55018634,repository_nwo:dickreuter/Poker,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/artificial-intelligence" title="Topic: artificial-intelligence">
#    artificial-intelligence
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:pokerstars,repository_id:55018634,repository_nwo:dickreuter/Poker,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/pokerstars" title="Topic: pokerstars">
#    pokerstars
#  </a>,
#  <a class="Link--muted" href="/dickreuter/Poker/stargazers">
#  <svg aria-label="star" class="octicon octicon-star" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg>
#                1.2k
#              </a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":2,"click_id":11211886,"result":{"id":11211886,"global_relay_id":"MDEwOlJlcG9zaXRvcnkxMTIxMTg4Ng==","model_name":"Repository","url":"https://github.com/pret/pokered"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="53ede5974202227802e18a352f936b69d996dbc8c5aa4d33e97cd78baed7e1e9" href="/pret/pokered">pret/<em>pokered</em></a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:pokemon,repository_id:11211886,repository_nwo:pret/pokered,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/pokemon" title="Topic: pokemon">
#    pokemon
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:reverse-engineering,repository_id:11211886,repository_nwo:pret/pokered,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/reverse-engineering" title="Topic: reverse-engineering">
#    reverse-engineering
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:gameboy,repository_id:11211886,repository_nwo:pret/pokered,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/gameboy" title="Topic: gameboy">
#    gameboy
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:disassembly,repository_id:11211886,repository_nwo:pret/pokered,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/disassembly" title="Topic: disassembly">
#    disassembly
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:gbz80,repository_id:11211886,repository_nwo:pret/pokered,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/gbz80" title="Topic: gbz80">
#    gbz80
#  </a>,
#  <a class="Link--muted" href="/pret/pokered/stargazers">
#  <svg aria-label="star" class="octicon octicon-star" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg>
#                3.1k
#              </a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":3,"click_id":60441516,"result":{"id":60441516,"global_relay_id":"MDEwOlJlcG9zaXRvcnk2MDQ0MTUxNg==","model_name":"Repository","url":"https://github.com/ishikota/PyPokerEngine"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="8d0fb5ef4d96ac1b85e610e65a7775f3af906e24865c68af0281445dc71e3f16" href="/ishikota/PyPokerEngine">ishikota/Py<em>Poker</em>Engine</a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:reinforcement-learning,repository_id:60441516,repository_nwo:ishikota/PyPokerEngine,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/reinforcement-learning" title="Topic: reinforcement-learning">
#    reinforcement-learning
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:ai-poker-game,repository_id:60441516,repository_nwo:ishikota/PyPokerEngine,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/ai-poker-game" title="Topic: ai-poker-game">
#    ai-poker-game
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:poker-engine,repository_id:60441516,repository_nwo:ishikota/PyPokerEngine,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/poker-engine" title="Topic: poker-engine">
#    poker-engine
#  </a>,
#  <a class="Link--muted" href="/ishikota/PyPokerEngine/stargazers">
#  <svg aria-label="star" class="octicon octicon-star" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg>
#                437
#              </a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":4,"click_id":9687103,"result":{"id":9687103,"global_relay_id":"MDEwOlJlcG9zaXRvcnk5Njg3MTAz","model_name":"Repository","url":"https://github.com/andrewprock/pokerstove"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="28e5a210bdfa2acb0c46e17d2b6e3fcc0663a16f759e454ac1d01e79b0e1c3f7" href="/andrewprock/pokerstove">andrewprock/<em>pokerstove</em></a>,
#  <a class="Link--muted" href="/andrewprock/pokerstove/stargazers">
#  <svg aria-label="star" class="octicon octicon-star" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg>
#                670
#              </a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":5,"click_id":24036336,"result":{"id":24036336,"global_relay_id":"MDEwOlJlcG9zaXRvcnkyNDAzNjMzNg==","model_name":"Repository","url":"https://github.com/pokerregion/poker"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="4db40b573407abcce83739521b76ff24510d08e633760a86f9478d5a3cd7d158" href="/pokerregion/poker">pokerregion/<em>poker</em></a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:poker,repository_id:24036336,repository_nwo:pokerregion/poker,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/poker" title="Topic: poker">
#    poker
#  </a>,
#  <a class="Link--muted" href="/pokerregion/poker/stargazers">
#  <svg aria-label="star" class="octicon octicon-star" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg>
#                275
#              </a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":6,"click_id":14155066,"result":{"id":14155066,"global_relay_id":"MDEwOlJlcG9zaXRvcnkxNDE1NTA2Ng==","model_name":"Repository","url":"https://github.com/geobalas/Poker"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="d5ca24651c90e73857c893cade9e0ef9cce4de08a2eccda98428727c10c15ecc" href="/geobalas/Poker">geobalas/<em>Poker</em></a>,
#  <a class="Link--muted" href="/geobalas/Poker/stargazers">
#  <svg aria-label="star" class="octicon octicon-star" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg>
#                168
#              </a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":7,"click_id":50256891,"result":{"id":50256891,"global_relay_id":"MDEwOlJlcG9zaXRvcnk1MDI1Njg5MQ==","model_name":"Repository","url":"https://github.com/pret/pokeruby"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="04b892e5a89a87232063a617ce9835502238ce11e1f78813f33cf687cab1f3cc" href="/pret/pokeruby">pret/<em>pokeruby</em></a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:pokemon,repository_id:50256891,repository_nwo:pret/pokeruby,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/pokemon" title="Topic: pokemon">
#    pokemon
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:reverse-engineering,repository_id:50256891,repository_nwo:pret/pokeruby,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/reverse-engineering" title="Topic: reverse-engineering">
#    reverse-engineering
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:c,repository_id:50256891,repository_nwo:pret/pokeruby,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/c" title="Topic: c">
#    c
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:gameboy-advance,repository_id:50256891,repository_nwo:pret/pokeruby,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/gameboy-advance" title="Topic: gameboy-advance">
#    gameboy-advance
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:decompilation,repository_id:50256891,repository_nwo:pret/pokeruby,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/decompilation" title="Topic: decompilation">
#    decompilation
#  </a>,
#  <a class="Link--muted" href="/pret/pokeruby/stargazers">
#  <svg aria-label="star" class="octicon octicon-star" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg>
#                585
#              </a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":8,"click_id":233256635,"result":{"id":233256635,"global_relay_id":"MDEwOlJlcG9zaXRvcnkyMzMyNTY2MzU=","model_name":"Repository","url":"https://github.com/fedden/poker_ai"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="8036a72f948b55980064305ef88a41ba8993373ee2c8e5b08aaaf83bd0e88a43" href="/fedden/poker_ai">fedden/<em>poker</em>_ai</a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:python,repository_id:233256635,repository_nwo:fedden/poker_ai,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/python" title="Topic: python">
#    python
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:open-source,repository_id:233256635,repository_nwo:fedden/poker_ai,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/open-source" title="Topic: open-source">
#    open-source
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:machine-learning,repository_id:233256635,repository_nwo:fedden/poker_ai,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/machine-learning" title="Topic: machine-learning">
#    machine-learning
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:artificial-intelligence,repository_id:233256635,repository_nwo:fedden/poker_ai,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/artificial-intelligence" title="Topic: artificial-intelligence">
#    artificial-intelligence
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:poker-engine,repository_id:233256635,repository_nwo:fedden/poker_ai,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/poker-engine" title="Topic: poker-engine">
#    poker-engine
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:texas-holdem-poker,repository_id:233256635,repository_nwo:fedden/poker_ai,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/texas-holdem-poker" title="Topic: texas-holdem-poker">
#    texas-holdem-poker
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:counterfactual-regret-minimization,repository_id:233256635,repository_nwo:fedden/poker_ai,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/counterfactual-regret-minimization" title="Topic: counterfactual-regret-minimization">
#    counterfactual-regret-minimization
#  </a>,
#  <a class="topic-tag topic-tag-link f6 px-2 mx-0" data-ga-click="Topic, search results" data-octo-click="topic_click" data-octo-dimensions="topic:pluribus,repository_id:233256635,repository_nwo:fedden/poker_ai,repository_public:true,repository_is_fork:false" data-view-component="true" href="/topics/pluribus" title="Topic: pluribus">
#    pluribus
#  </a>,
#  <a class="Link--muted" href="/fedden/poker_ai/stargazers">
#  <svg aria-label="star" class="octicon octicon-star" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg>
#                768
#              </a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":9,"click_id":4288453,"result":{"id":4288453,"global_relay_id":"MDEwOlJlcG9zaXRvcnk0Mjg4NDUz","model_name":"Repository","url":"https://github.com/pokerth/pokerth"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="3c17cfef2d373488cc1562dc1d2c34b1a4191207c03276486244d9a42a5214a4" href="/pokerth/pokerth">pokerth/<em>pokerth</em></a>,
#  <a class="Link--muted" href="/pokerth/pokerth/stargazers">
#  <svg aria-label="star" class="octicon octicon-star" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg>
#                398
#              </a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":10,"click_id":34187618,"result":{"id":34187618,"global_relay_id":"MDEwOlJlcG9zaXRvcnkzNDE4NzYxOA==","model_name":"Repository","url":"https://github.com/CharlieHess/slack-poker-bot"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="4f255f853525f169aac55f4fd45961ced6b792127ba28620c2cdc404eafb4748" href="/CharlieHess/slack-poker-bot">CharlieHess/slack-<em>poker</em>-bot</a>,
#  <a class="Link--muted" href="/CharlieHess/slack-poker-bot/stargazers">
#  <svg aria-label="star" class="octicon octicon-star" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg>
#                1.7k
#              </a>,
#  <a aria-label="Page 2" href="/search?p=2&amp;q=poker&amp;type=Repositories" rel="next">2</a>,
#  <a aria-label="Page 3" href="/search?p=3&amp;q=poker&amp;type=Repositories">3</a>,
#  <a aria-label="Page 4" href="/search?p=4&amp;q=poker&amp;type=Repositories">4</a>,
#  <a aria-label="Page 5" href="/search?p=5&amp;q=poker&amp;type=Repositories">5</a>,
#  <a aria-label="Page 99" href="/search?p=99&amp;q=poker&amp;type=Repositories">99</a>,
#  <a aria-label="Page 100" href="/search?p=100&amp;q=poker&amp;type=Repositories">100</a>,
#  <a class="next_page" href="/search?p=2&amp;q=poker&amp;type=Repositories" rel="next">Next</a>,
#  <a class="f6" href="/search/advanced?q=poker">Advanced search</a>,
#  <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
#  <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
#  <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
#  </svg>
#  </a>,
#  <a data-analytics-event='{"category":"Footer","action":"go to terms","label":"text:terms"}' href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a>,
#  <a data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a>,
#  <a data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' href="https://github.com/security">Security</a>,
#  <a data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' href="https://www.githubstatus.com/">Status</a>,
#  <a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a>,
#  <a data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' href="https://support.github.com?tags=dotcom-footer">Contact GitHub</a>,
#  <a data-analytics-event='{"category":"Footer","action":"go to Pricing","label":"text:Pricing"}' href="https://github.com/pricing">Pricing</a>,
#  <a data-analytics-event='{"category":"Footer","action":"go to api","label":"text:api"}' href="https://docs.github.com">API</a>,
#  <a data-analytics-event='{"category":"Footer","action":"go to training","label":"text:training"}' href="https://services.github.com">Training</a>,
#  <a data-analytics-event='{"category":"Footer","action":"go to blog","label":"text:blog"}' href="https://github.blog">Blog</a>,
#  <a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a>,
#  <a href="">Reload</a>,
#  <a href="">Reload</a>]

# %%
soup.find_all('a[href]')
# Out:
# []

# %%
soup.find_all('div', class_='fa text-normal')
# Out:
# []

# %%
soup.find_all('a', class_ = 'v-align-middle')
# Out:
# [<a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":1,"click_id":55018634,"result":{"id":55018634,"global_relay_id":"MDEwOlJlcG9zaXRvcnk1NTAxODYzNA==","model_name":"Repository","url":"https://github.com/dickreuter/Poker"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="e1766e31a417865d8259e97fcfbe3552e5b99662e161136ccceb94deb40ddae6" href="/dickreuter/Poker">dickreuter/<em>Poker</em></a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":2,"click_id":11211886,"result":{"id":11211886,"global_relay_id":"MDEwOlJlcG9zaXRvcnkxMTIxMTg4Ng==","model_name":"Repository","url":"https://github.com/pret/pokered"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="53ede5974202227802e18a352f936b69d996dbc8c5aa4d33e97cd78baed7e1e9" href="/pret/pokered">pret/<em>pokered</em></a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":3,"click_id":60441516,"result":{"id":60441516,"global_relay_id":"MDEwOlJlcG9zaXRvcnk2MDQ0MTUxNg==","model_name":"Repository","url":"https://github.com/ishikota/PyPokerEngine"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="8d0fb5ef4d96ac1b85e610e65a7775f3af906e24865c68af0281445dc71e3f16" href="/ishikota/PyPokerEngine">ishikota/Py<em>Poker</em>Engine</a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":4,"click_id":9687103,"result":{"id":9687103,"global_relay_id":"MDEwOlJlcG9zaXRvcnk5Njg3MTAz","model_name":"Repository","url":"https://github.com/andrewprock/pokerstove"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="28e5a210bdfa2acb0c46e17d2b6e3fcc0663a16f759e454ac1d01e79b0e1c3f7" href="/andrewprock/pokerstove">andrewprock/<em>pokerstove</em></a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":5,"click_id":24036336,"result":{"id":24036336,"global_relay_id":"MDEwOlJlcG9zaXRvcnkyNDAzNjMzNg==","model_name":"Repository","url":"https://github.com/pokerregion/poker"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="4db40b573407abcce83739521b76ff24510d08e633760a86f9478d5a3cd7d158" href="/pokerregion/poker">pokerregion/<em>poker</em></a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":6,"click_id":14155066,"result":{"id":14155066,"global_relay_id":"MDEwOlJlcG9zaXRvcnkxNDE1NTA2Ng==","model_name":"Repository","url":"https://github.com/geobalas/Poker"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="d5ca24651c90e73857c893cade9e0ef9cce4de08a2eccda98428727c10c15ecc" href="/geobalas/Poker">geobalas/<em>Poker</em></a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":7,"click_id":50256891,"result":{"id":50256891,"global_relay_id":"MDEwOlJlcG9zaXRvcnk1MDI1Njg5MQ==","model_name":"Repository","url":"https://github.com/pret/pokeruby"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="04b892e5a89a87232063a617ce9835502238ce11e1f78813f33cf687cab1f3cc" href="/pret/pokeruby">pret/<em>pokeruby</em></a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":8,"click_id":233256635,"result":{"id":233256635,"global_relay_id":"MDEwOlJlcG9zaXRvcnkyMzMyNTY2MzU=","model_name":"Repository","url":"https://github.com/fedden/poker_ai"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="8036a72f948b55980064305ef88a41ba8993373ee2c8e5b08aaaf83bd0e88a43" href="/fedden/poker_ai">fedden/<em>poker</em>_ai</a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":9,"click_id":4288453,"result":{"id":4288453,"global_relay_id":"MDEwOlJlcG9zaXRvcnk0Mjg4NDUz","model_name":"Repository","url":"https://github.com/pokerth/pokerth"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="3c17cfef2d373488cc1562dc1d2c34b1a4191207c03276486244d9a42a5214a4" href="/pokerth/pokerth">pokerth/<em>pokerth</em></a>,
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"poker","result_position":10,"click_id":34187618,"result":{"id":34187618,"global_relay_id":"MDEwOlJlcG9zaXRvcnkzNDE4NzYxOA==","model_name":"Repository","url":"https://github.com/CharlieHess/slack-poker-bot"},"originating_url":"https://github.com/search?q=poker","user_id":null}}' data-hydro-click-hmac="4f255f853525f169aac55f4fd45961ced6b792127ba28620c2cdc404eafb4748" href="/CharlieHess/slack-poker-bot">CharlieHess/slack-<em>poker</em>-bot</a>]

# %%
# build the categories from inshorts.com/en/read. We can use list methods to custom format it too (lower, drop the misc category, etc)
repos = [a.text for a in soup.find_all('a', class_='v-align-middle')]

repos
# Out:
# ['dickreuter/Poker',
#  'pret/pokered',
#  'ishikota/PyPokerEngine',
#  'andrewprock/pokerstove',
#  'pokerregion/poker',
#  'geobalas/Poker',
#  'pret/pokeruby',
#  'fedden/poker_ai',
#  'pokerth/pokerth',
#  'CharlieHess/slack-poker-bot']

# %%
url = 'https://github.com/search?p={i}&q=poker&type=Repositories'

# %%
url = 'https://github.com/search?p={i}&q=poker&type=Repositories'
headers = {"Authorization": f"token {github_token}", "User-Agent": github_username}
response = get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
import os
import json
from typing import Dict, List, Optional, Union, cast
from requests import get
from bs4 import BeautifulSoup
import time
import acquire

from env import github_token, github_username


def get_repos(n):
    all_repos = []
    for page in range(1, n):
        url = f'https://github.com/search?p={page}&q=poker&type=Repositories'
        headers = {"Authorization": f"token {github_token}", "User-Agent": github_username}
        while True:
            response = get(url, headers=headers)
            if response.ok:
                break
            else:
                time.sleep(15)
        soup = BeautifulSoup(response.text, 'html.parser')
        repo = [a.text for a in soup.find_all('a', class_='v-align-middle')]
        all_repos = all_repos + repo
        print(f'\rFetching page {page} of {n-1} {url}', end='')
    return all_repos
# Out:
# Fetching page 50 of 50 https://github.com/search?p=50&q=poker&type=Repositories

# %%
get_repos(5)
# Out:
# Fetching page 4 of 4 https://github.com/search?p=4&q=poker&type=Repositories
# ['dickreuter/Poker',
#  'pret/pokered',
#  'ishikota/PyPokerEngine',
#  'andrewprock/pokerstove',
#  'pokerregion/poker',
#  'geobalas/Poker',
#  'pret/pokeruby',
#  'fedden/poker_ai',
#  'pokerth/pokerth',
#  'CharlieHess/slack-poker-bot',
#  'EricSteinberger/PokerRL',
#  'Toxantron/scrumonline',
#  'richarcher/Hatjitsu',
#  'jacobhyphenated/PokerServer',
#  'goldfire/pokersolver',
#  'worldveil/deuces',
#  'kwai/DouZero',
#  'HenryRLee/PokerHandEvaluator',
#  'alexyz/poker',
#  'dickreuter/neuron_poker',
#  'iloveponies/p-p-p-pokerface',
#  'chenosaurus/poker-evaluator',
#  'Tairraos/Poker.JS',
#  'hippich/Bitcoin-Poker-Room',
#  'mjhbell/node-poker',
#  'tianlanlandelan/poker',
#  'Zuehlke/poinz',
#  'christophschmalhofer/poker',
#  'zifeiy/poker-game-demo',
#  'redbooth/scrum-poker-cards',
#  'mdp/JsPoker',
#  'Jeremiah9000/Poker-with-Python',
#  'ginuerzh/poker',
#  'rundef/node-poker-odds-calculator',
#  'wdmir/521266750_qq_com',
#  'datamllab/rlcard',
#  'Wizehive/firepoker',
#  'WangAnXin/poker',
#  'HHSmithy/PokerHandHistoryParser',
#  'iWeslie/PokerCard']

# %%
REPOS = get_repos(51)
# Out:
# Fetching page 50 of 50 https://github.com/search?p=50&q=poker&type=Repositories

# %%
REPOS
# Out:
# ['dickreuter/Poker',
#  'pret/pokered',
#  'ishikota/PyPokerEngine',
#  'andrewprock/pokerstove',
#  'pokerregion/poker',
#  'geobalas/Poker',
#  'pret/pokeruby',
#  'fedden/poker_ai',
#  'pokerth/pokerth',
#  'CharlieHess/slack-poker-bot',
#  'EricSteinberger/PokerRL',
#  'Toxantron/scrumonline',
#  'richarcher/Hatjitsu',
#  'jacobhyphenated/PokerServer',
#  'goldfire/pokersolver',
#  'worldveil/deuces',
#  'kwai/DouZero',
#  'HenryRLee/PokerHandEvaluator',
#  'alexyz/poker',
#  'dickreuter/neuron_poker',
#  'iloveponies/p-p-p-pokerface',
#  'chenosaurus/poker-evaluator',
#  'Tairraos/Poker.JS',
#  'hippich/Bitcoin-Poker-Room',
#  'mjhbell/node-poker',
#  'tianlanlandelan/poker',
#  'Zuehlke/poinz',
#  'christophschmalhofer/poker',
#  'zifeiy/poker-game-demo',
#  'redbooth/scrum-poker-cards',
#  'mdp/JsPoker',
#  'Jeremiah9000/Poker-with-Python',
#  'ginuerzh/poker',
#  'rundef/node-poker-odds-calculator',
#  'wdmir/521266750_qq_com',
#  'datamllab/rlcard',
#  'Wizehive/firepoker',
#  'WangAnXin/poker',
#  'HHSmithy/PokerHandHistoryParser',
#  'iWeslie/PokerCard',
#  'lxr1907/pokers',
#  'brunoscopelliti/poker-holdem-engine',
#  'doctording/pomelo_unity_poker_game',
#  'vampserv/node-poker-stack',
#  'shuimuliang/qnmahjongserver',
#  'floatinghotpot/casino-server',
#  'dgurkaynak/slack-poker-planner',
#  'cschleiden/azure-boards-estimate',
#  'moscow25/deep_draw',
#  'NikolayIT/TexasHoldemGameEngine',
#  'StevenWeathers/thunderdome-planning-poker',
#  'chasembowers/poker-learn',
#  'robolson/ruby-poker',
#  'int8/counterfactual-regret-minimization',
#  'ishikota/PyPokerGUI',
#  'tansey/pycfr',
#  'dannye/pokered-gbc',
#  'chehsunliu/poker',
#  'lifrordi/DeepStack-Leduc',
#  'lbdmxhs/poker',
#  'adamsmith/game-theory-poker',
#  'rosbo/texas-holdem-poker-ai',
#  'pierotofy/PokerMuck',
#  'rotembcohen/pokerBuddyApp',
#  'elpassion/sprint-poker',
#  'sixteenstudio/poker',
#  'russ/openpoker',
#  'ivegner/PokerOmega',
#  'duracellko/planningpoker4azure',
#  'therewillbecode/react-poker',
#  'disdain13/PokeRoadie',
#  'AvengerMoJo/TexasHoldem',
#  'dolotech/Texas-Hold-em-Poker',
#  'pokermania/pokereval',
#  'yongkangchen/poker-client',
#  'bubuntux/poker-engine',
#  'KanishkT123/PokerBot',
#  'aliang/pokerhand-eval',
#  'pokermania/pokernetwork',
#  'mdp/MachinePoker',
#  'atinm/poker-eval',
#  'ashelly/ACE_eval',
#  'michalp21/coms4995-finalproj',
#  'zekyll/OMPEval',
#  'diditforlulz273/PokerRL-Omaha',
#  'benjy3gg/pokeRadar',
#  'bitcoinbrisbane/BitPoker',
#  'yongkangchen/poker-server',
#  'cookpete/poker-odds',
#  'apehex/awesome-poker',
#  'IanSullivan/PokerCFR',
#  'jacobhyphenated/AndroidPokerPlayer',
#  'DevMountain/tic-tac-toe-poker',
#  'matheusml/pwa-planning-poker',
#  'goodspb/poker-algorithm',
#  'v2k/poker-eval',
#  'saschpe/PlanningPoker',
#  'notnil/joker',
#  'lizzie2008/ChinesePoker',
#  'dmorrill10/acpc_poker_gui_client',
#  'aslakhellesoy/poker',
#  'atinm/fpdb',
#  'epifab/pypoker',
#  'bimovidia/planning-poker',
#  'IFS49F/poker',
#  'phstc/javapokertexasholdem',
#  'tokafish/elixir_poker',
#  'Mikhail-MM/React-Poker',
#  'spni/spni.github.io',
#  'ozzi7/Poker-MCCFRM',
#  'coding-blocks/poker',
#  'monicanagent/cypherpoker',
#  'Bryanx/poker',
#  'WayneYe/ScrumPoker',
#  'donnemartin/poker',
#  'pandaant/poker-cfrm',
#  'PhillipTaylor/PokerServer',
#  'dirusali/pokerodds',
#  'code-squad/swift-pokergameapp',
#  'carwow/pokerwars',
#  'rocketacademy/video-poker-bootcamp',
#  'somnusand/Poker',
#  'ylboerner/easyPokerHUD',
#  'andyxhadji/Simple-Poker',
#  'halomademeapc/pokeR',
#  'pokermania/pokerengine',
#  'forestturner/PokerHandRangeCalc',
#  'thlorenz/phe',
#  'schalermthai/pokerhand',
#  'czanoci/Poker',
#  'kripod/mental-poker',
#  'wzdwc/TexasPokerGame',
#  'siimon/Web-Planning-Poker',
#  'igreshev/lightning-poker',
#  'Rainist/pycon-2018-banksalad-holdem',
#  'siavashg87/poker-odds-calc',
#  'philroberts/FPDB-for-OSX',
#  'robopoker/robopoker',
#  'acebusters/acebusters-frontend',
#  'rggibson/open-pure-cfr',
#  'theaigames/poker-engine',
#  'ngokevin/pokery',
#  'scrumpypoker/i18n',
#  'wolo-research/bulldog',
#  'conch76/poker',
#  'DogLooksGood/holdem',
#  'scascar/PokerDeepLearning',
#  'erichkeane/poker2firmwarehacking',
#  'inovex/planning-poker',
#  'whatsdis/pluribus',
#  'ningowood/poker',
#  'evandam/Poker',
#  'elliottneilclark/rs-poker',
#  'allenfrostline/PokerHandsDataset',
#  'NextZeus/poker',
#  'miguelzf/PokerBot',
#  'Ian-MacLeod/Poker-Solver',
#  'AlgorithmsMeetup/PokerHands',
#  'Fubinator/planning-poker-discord-bot',
#  'mdp/hoyle',
#  'VitamintK/pluribus-hand-parser',
#  'nateyolles/slack-pokerbot',
#  'UPRM-Advanced-Programming-Course/PokerMemory',
#  'jgao18/PokerRoom',
#  'near-examples/poker',
#  'wajahatkarim3/EasyFlipView',
#  'ta-data-mexpt/-lab-poker-master',
#  'itb-ie/poker',
#  'ethnt/poker',
#  'mikhailshilkov/FsPokerLogic',
#  'pusabless/texas-poker-engine',
#  'pret/pokerevo',
#  'tsuntsuntsuntsun/Pokerbot',
#  'ta-data-mex/lab-poker-master',
#  'venil7/ScrumPoker',
#  'matthewkennedy5/Poker',
#  'jacobhyphenated/iPadPokerGameClient',
#  'pokerwars/pokerwars.io-starterbot-python',
#  'androidjp/TDD-poker-hands',
#  'Pokereum/pokereum',
#  'rafanoronha/scala-poker',
#  'dperezcabrera/jpoker',
#  'yule/poker-croupier',
#  'qJake/planning-poker',
#  'garyjh126/MLFYP_Project',
#  'wangzi6147/TexasPoker',
#  'luk3vn/web-poker',
#  'AndrejsAbrickis/PlanningPoker',
#  'codescape/jira-scrum-poker',
#  'EvgenyKashin/TensorPoker',
#  'aneopsy/PokerStats',
#  'changhongyan123/mypoker',
#  'jfilliben/poker-sim',
#  'vikas0sharma/ScrumPoker',
#  'zkayser/poker_ex',
#  'thlorenz/hhp',
#  'amiller/instant-poker',
#  'redbooth/planning-time-android',
#  'fangdejia/HwTexasPoker',
#  'surranc20/pokered',
#  'buhrmi/svelte-poker',
#  'PhillipTaylor/texas_holdem',
#  'BlockChainClub/PokerGame',
#  'ylmbtm/PokerCraker',
#  'ozeidan/pokerBot',
#  'kmurf1999/rust_poker',
#  'J-Burnett/PokerPlayer',
#  'pattern/react-poker',
#  'microsoft/matchem-poker-wp',
#  'codesquad-members-2022/swift-pokergame',
#  'onevcat/TexasPoker',
#  'mcostalba/poker',
#  'wwttaozong/Poker',
#  'puzza007/openpoker',
#  'samcoppini/Discord-Poker-Bot',
#  'sky068/PokerLandlord',
#  'dannye/pokered-gen-II',
#  'cschweda/vue-poker',
#  'philou/planning-poker',
#  'bcgraham/pokerserver',
#  'chips-blockchain/pangea-poker',
#  'JaviSoto/SwiftPoker',
#  'wdi-sg/poker_refactor',
#  'nberardi/consensus',
#  'hellomuthu23/planning-poker',
#  'cortesoft/PokerMatic',
#  'ChrisZieba/holdem',
#  'ericdke/PokerHands',
#  'Fossana/cplusplus-cfr-poker-solver',
#  'monicanagent/cypherpoker.js',
#  'tom555cat/Poker2048',
#  'ZenithPoker/ZippySolver',
#  'cornernote/autoit-poker_bot',
#  'gorel/C-Poker-AI',
#  'lxr1907/pokers-server',
#  'wkantaros/cloudpoker',
#  'ethansbrown/acpc',
#  'fattigerlee/poker',
#  'Monadical-SAS/oddslingers.poker',
#  'Hazem-Ben-Khalfallah/scrum-poker-planning',
#  'bcldvd/real-time-planning-poker',
#  'Sharp-Data/Data-Science-Poker-Projects',
#  'jtushman/pivotal_tools',
#  'tansey/js_poker',
#  'ericgjackson/slumbot2019',
#  'TheScarletSword/pokereddeluxe',
#  'iOS-Dev-Kurs/poker',
#  'pcafstockf/PokerFace',
#  'platatat/SnapCall',
#  'mr-feek/global-poker-hand-history-converter-chrome-extension',
#  'predrag-njegovanovic/poker-hand-recognition',
#  'CoinPokerOfficial/poker-decentralized-rng',
#  'Malonrio/Cocos-Shader-Poker',
#  'cwoolner/flex-poker',
#  'ptwu/distributed-texasholdem',
#  'drewtorg/poker',
#  'TNG/next-generation-scrum-poker',
#  'chmccc/poker',
#  'cmccabe/poker-odds',
#  'lean-poker/poker-player-js',
#  'notsapinho/powercord-together',
#  'genjix/kartludox',
#  'gorel/pokerAI',
#  'sudocrystal/CS2-Poker',
#  'BoiseCodeWorks/VideoPoker',
#  'mjwestcott/pypokertools',
#  'yociduo/scrum-planning-poker',
#  'soederpop/poker',
#  'danielmiladinov/Poker',
#  'andrewprock/jpoker',
#  'DabeLong/Two-Card-Poker-CFR-AI',
#  'allenfrostline/Poker',
#  'StefanKarpinski/Cards.jl',
#  'magnusmickelsson/pokeraidbot',
#  'JohnnyJayJay/poker',
#  'axross/aqua',
#  'reutsharabani/minipoker',
#  'udacity/CppND-Game-Server',
#  'zanussbaum/pluribus',
#  'ashelly/PET',
#  'sbnb/poker-js',
#  'huangzy77/PokerRobot',
#  'pokerplatform/Full-Online-Poker-Platform',
#  'Lemoncode/planning-poker-example',
#  'worldveil/gopoker',
#  'peterjiawhite/Superhuman_AI_in_multiplayer_poker_-',
#  'Harpspiel/NewPoker',
#  'marhs/pokerai',
#  'nbcx/poker',
#  'philipok-1/Poker',
#  'guipenedo/PokeRadar',
#  'feliciosan/PokerIT',
#  'miniharryc/poker',
#  'huntrar/PokerNet',
#  'betboy/texas',
#  'codeKonami/poker-hand',
#  'tythorsen/planning-poker',
#  'rundef/poker-odds-calculator',
#  'xcanchal/scrum-poker',
#  'Cysha/casino-holdem',
#  'zygmuntz/kaggle-poker-hands',
#  'brandinho/Poker-Probability-Approximation',
#  'aprey10/open-poker',
#  'kvesteri/python-poker',
#  'cgnicholls/rlpoker',
#  'ynd/poker',
#  'Karsens/pluribus-poker-bot-js',
#  'fogleman/Poker',
#  'boolean-uk/js-poker-challenge',
#  'mouhyi/Poker321',
#  'StarFlight/Poker-Galore',
#  'kennethshackleton/SKPokerEval',
#  'aniliyidogan/screm.co',
#  'sintefmath/QuantumPoker',
#  'zachwaugh/Helveticards',
#  'pokemium/pokered-docs-ja',
#  'Dsummers91/Ethereum-Poker-Dapp',
#  'mikemelch/Card-Games',
#  'rdepena/planningpoker',
#  'nbouscal/poker.hs',
#  'Sanqui/pokered-randomizer',
#  'nidhik/cubeia-agpl',
#  'HerdADVance/maker-holdem',
#  'aditisrinivas97/Pokerman',
#  'CWSites/Poker',
#  'kdub0/hand-isomorphism',
#  'zkayser/pokerex_client',
#  'deltacluse/Tkinter_Poker',
#  'dickreuter/PokerEquityCalculator',
#  'tshadowknight/Pokemon-Roaming-Red',
#  'lean-poker/poker-player-ruby',
#  'vpj/poker',
#  'pokereosteam/PokerEOS',
#  'itb-ie/poker_homework',
#  'valterbarros/scrum-poker',
#  'ryan112358/poker-bot',
#  'zxqx/poker',
#  'mingzijian/pokers',
#  'brucetie/pokerface',
#  'tangentforks/TwoPlusTwoHandEvaluator',
#  'EricSteinberger/Deep-CFR',
#  'steve-ng/pokerface-nft',
#  'thinkbox/poker-1',
#  'h3rc4r/lab-poker-odds',
#  'Mullen-High-School/Draw-Poker',
#  'Rangi42/polished-map',
#  'twa-camp-2016/poker-21',
#  'scrubmx/poker',
#  'edavis03/poker-hands',
#  'Froren/OpenToolchainPoker',
#  'vkolagotla/DevOpsPoker',
#  'Sebazzz/PokerTime',
#  'Deltanium/PokeRadar',
#  'WDI-SEA/poker_tournament',
#  'mettoboshi/poker-game',
#  'tamlhp/deepbot-poker',
#  'chrisjeng/Poker',
#  'GavinJoyce/PokerCards',
#  'VasylYaremkiv/poker',
#  'codejens/PokerGame',
#  'JosephYao/Kata-PokerHands',
#  'ucsb-cs56-projects/cs56-games-poker',
#  'haffizaliraza/poker-ruby',
#  'vilotchild/AwesomePokerGame',
#  'timhaley94/holdem',
#  'pandaant/poker-mcts',
#  'mangoknight/dexas-poker',
#  'Pobermeier/vintage-poker',
#  'icescrum/iceScrum-plugin-planning-poker',
#  'chips-blockchain/bet',
#  'mr-feek/global-poker-hand-history-converter',
#  'Fossana/discounted-cfr-poker-solver',
#  'kyrcha/poker',
#  'danielpaz6/Poker-Hand-Evaluator',
#  'tfbninja/Poker',
#  'GeekLaunch/poker',
#  'axross/poker',
#  'phipex/PokerTest',
#  'cs3243-project-group-18/poker-ai',
#  '3pillarlabs/scrumpoker',
#  'mihhailnovik/jSim',
#  'xcyuzhen/Poker_client_pomelo',
#  'jeffusan/yokohama-holdem',
#  'hlcfan/pokr',
#  'iamsap/poker',
#  'xumingthepoet/texas_poker',
#  'WDI-SEA/express-poker-teams',
#  'pokerth/pokerth-live',
#  'Z8264/poker-calculator',
#  'szantopeter/poker-player-java',
#  'pj4533/PokerNowGrabber',
#  'koffeinfrei/planning-poker',
#  'SoboLAN/pokerenlighter-simulator',
#  'ChengTsang/Potential-Aware-Abstraction-In-Texas-Hold-em-Poker',
#  'jjulian/pitboss',
#  'EricMWalton/Fast-Poker-Odds',
#  'byronsha/poker_playhouse',
#  'matt404/Pointing.Poker',
#  'sixteenstudio/poker-env',
#  'rux-pizza/poker-ai',
#  'Dosugamea/PokerBot',
#  'jamesmacaulay/poker-hands',
#  'karinqe/poker',
#  'GoldPoker/GoldPoker-coin',
#  'Dabomstew/pokered-speedchoice',
#  'boldpoker/poker-shuffle',
#  'Josh-TX/Poker',
#  'eduardo/planning-poker-timer',
#  'zanezgame/Poker',
#  'Gorazdo/Planning-Poker',
#  'ekzhu/planning-poker',
#  'melickm/OpenToolchainPoker',
#  'bovle/fixed_limit_poker',
#  'connor21/DevOpsPoker',
#  'mcwp98/pokernet',
#  'pj4533/PokerNowKit',
#  'aparrett/poker-ui-deprecated',
#  'luofanrain/poker',
#  'travisby/altcoinpokerjs',
#  'rrylee/phppoker',
#  'wizardwerdna/pokerstats',
#  'shige0501/android-sdk-pokeri',
#  'adityanaag3/planning-poker-salesforce',
#  'izqui/Poker.swift',
#  'Yaoir/VideoPoker-Go-WebAssembly',
#  'hh2010/hunl',
#  'digao-dalpiaz/Planning-Poker',
#  'xcyuzhen/Poker_server_pomelo',
#  'lzientek/pokerPlanning',
#  'Nisarg12/pokeruby-tools',
#  'ta-datapt-bcn/lab-poker-odds',
#  'Pik-9/PokerTH-Tracker',
#  'technologiespro/poker-core',
#  'mproberts/smallblind',
#  'beli-sk/pokercards',
#  'studiomobile/poker-eval-node',
#  'jamak/pokerbot',
#  'jacobhyphenated/JQMPokerPlayerClient',
#  'montyaahad/PokerStarsBot',
#  'tue-5ARA0-2021-Q3/poker-server-backend',
#  'huderlem/pokered_battle_factory',
#  'VoVampire/poker',
#  'LRFalk01/pokerboy',
#  'norkator/poker-pocket-backend',
#  'girving/poker',
#  'juhank/poker',
#  'Bitou2k/PokeRPG',
#  'aparrett/poker-api-deprecated',
#  'aha-develop/planning-poker',
#  'rdvdijk/ruby-poker',
#  'tomo-tomoarch/YokosukaPokerVer0.2',
#  'EmeraldCityProgrammingGroup/tracker_poker',
#  'COO-EACH-USP-2021/Poker-ACH2003-04',
#  'Zack-Tillotson/Simple-Poker-Classification',
#  'samuelneff/poker-tutorial',
#  'AussieSeaweed/pokerface',
#  'syurisuzuki/PokerAndCoinPusher',
#  'ostigter/texasholdem-java',
#  'Trantect/PlanningPoker',
#  'einstein95/pokered-de',
#  'kmurf1999/HoldemSolver',
#  'shige0501/android-sdk-pokeri-v2',
#  'jbPokerStarsSolutions/PokerStars-API',
#  'FilippoMandrini/Progetto-J',
#  'wangxiaomo/Poker',
#  'FrancoisHar/Poker',
#  'linuz/Facebook-Auto-Poker',
#  'CragonGame/CasinosClient',
#  'carlosreneas/parcialPoker',
#  'kabirsingh2004/Discord-Mini-Games-Bot',
#  'omarshammas/pyPoker-Texas-HoldEm',
#  'jonaskeisu/Poker',
#  'PolygeneLubricants/planning-poker',
#  'hsylx1992/Texas-Hold-em-poker-AI',
#  'Barros42/ShellBox-Planning-Poker',
#  'davidxmoody/mctsbot',
#  'flambaum/flame-poker',
#  'moneypool/ranking-poker-hands',
#  'ChornHulio/TexasHoldem',
#  'riddlesio/poker-engine-java',
#  'simbo1905/sprint-planning',
#  'RobertCorey/column-poker',
#  'bjrnmrtns/poker',
#  'treyarnold/poker-face',
#  'coffee4tw/poker-hhdb',
#  'mdashx/pangea-poker-frontend',
#  'tterava/PokerTrainingFramework',
#  'charlesabarnes/pointing-poker',
#  'phongcao/pokerbot',
#  'listingslab/react-playing-cards',
#  'nikita-volkov/ptr-poker',
#  'beachgrub/PokerHandSolidity',
#  'nowakowsky/PokerStars',
#  'Ahineya/js-workshop-poker-boilerplate',
#  'David-H-Bolton/PokerEval',
#  'IMGameDesigner/PokerGame',
#  'houen/PokerFace',
#  'ngocbd/pokerserver',
#  'mikaelbr/AI-Poker-Player',
#  'ProPanek/PlanningPoker']
